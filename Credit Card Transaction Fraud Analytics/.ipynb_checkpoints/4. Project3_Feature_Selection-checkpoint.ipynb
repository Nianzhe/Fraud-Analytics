# %%
import pandas as pd
import numpy as np
import random

# %%
v = pd.read_csv('final_variable.csv')

# %%
v[['Fraud','cardnum-merch_state_merch_zip_count30__mean']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96397 entries, 0 to 96396
# Data columns (total 2 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Fraud                                        96397 non-null  int64
#  1   cardnum-merch_state_merch_zip_count30__mean  96397 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 1.5 MB

# %%
v.columns
# Out:
# Index(['Recnum', 'cardnum-merch_state_merch_zip_count30__sum',
#        'cardnum-merch_state_merch_zip_count30__mean',
#        'cardnum-merch_state_merch_zip_count30__max',
#        'cardnum-merch_state_merch_zip_count30__median',
#        'cardnum-merch_state_merch_zip_count30__actual_sum',
#        'cardnum-merch_state_merch_zip_count30__actual_avg',
#        'cardnum-merch_state_merch_zip_count30__actual_max',
#        'cardnum-merch_state_merch_zip_count30__actual_median',
#        'cardnum-merch_state_merch_zip_count14__sum',
#        ...
#        'Merch_description_part_1_sum7_sum_ratio',
#        'Merch_description_part_1_count14_count_ratio',
#        'Merch_description_part_1_sum14_sum_ratio',
#        'Merch_description_part_1_count30_count_ratio',
#        'Merch_description_part_1_sum30_sum_ratio', 'day_week_risk', 'rand',
#        'Fraud', 'U_star_card', 'U_star_merch'],
#       dtype='object', length=482)

# %%
v = v[(v.Recnum <=84299) & (v.Recnum >= 3338)]

# %%
v = v.set_index('Recnum')

# %%
from scipy import stats

# %%
KSFDR = pd.DataFrame(columns = ['ks'])

# %%
goods = v[v['Fraud'] == 0]
bads = v[v['Fraud'] == 1]

# %%
i = 0
for column in list(v.columns):
    KSFDR.loc[i,'ks'] = stats.ks_2samp(goods[column],bads[column])[0]
    i = i+1

# %%
KSFDR.index = v.columns

# %%
KSFDR = KSFDR.reset_index()

# %%
KSFDR.sort_values('ks',ascending = False)
# Out:
#                                             index         ks
# 478                                         Fraud          1
# 16      cardnum-merch_state_merch_zip_count7__sum   0.686302
# 64                  cardnum-merch_zip_count7__sum   0.686226
# 160    cardnum-merch_description_part_count7__sum   0.685689
# 208                  cardnum-merchnum_count7__sum   0.682645
# ..                                            ...        ...
# 286     Merch_description_part_count0__actual_max  0.0976838
# 468  Merch_description_part_0_count30_count_ratio  0.0965971
# 470   Merch_description_part_1_count7_count_ratio  0.0944927
# 440                  Cardnum_0_count7_count_ratio  0.0782477
# 477                                          rand  0.0287516
#
# [481 rows x 2 columns]

# %%
numbads = len(bads)

# %%
topRows = int(round(len(v)*0.03))
j = 0
for column in v.columns:
    if column != 'Fraud':
        temp1 = v[[column,'Fraud']].sort_values(column,ascending=False).head(topRows)
        temp2 = v[[column,'Fraud']].sort_values(column,ascending=True).head(topRows)
        needed1 = temp1.loc[:,'Fraud']
        needed2 = temp2.loc[:,'Fraud']
        FDR1 = sum(needed1)/numbads
        FDR2 = sum(needed2)/numbads
        FDRate = np.maximum(FDR1,FDR2)
        KSFDR.loc[j, 'FDR'] = FDRate
        j = j +1
    else:
        KSFDR.loc[j, 'FDR'] = 1
        j = j+1

# %%
KSFDR['KS_rank'] = KSFDR['ks'].rank(axis = 0)
KSFDR['FDR_rank'] = KSFDR['FDR'].rank(axis = 0)
KSFDR['Average_rank'] = (KSFDR['KS_rank'] + KSFDR['FDR_rank'])/2

# %%
KSFDR.sort_values(['Average_rank']).tail(81)
# Out:
#                                           index        ks       FDR  KS_rank  \
# 362                         Cardnum_count3__max  0.561303  0.456221    353.0
# 370                         Cardnum_count1__max  0.570391  0.430876    370.0
# 354                         Cardnum_count7__max  0.558802  0.489631    343.0
# 304                        Merchnum_count7__sum  0.588808  0.345622    399.0
# 274          Merch_description_part_count1__max  0.578145  0.442396    383.0
# ..                                          ...       ...       ...      ...
# 24    cardnum-merch_state_merch_zip_count3__sum  0.678832  0.641705    475.0
# 168  cardnum-merch_description_part_count3__sum  0.680444  0.641705    476.0
# 64                cardnum-merch_zip_count7__sum  0.686226  0.638249    479.0
# 16    cardnum-merch_state_merch_zip_count7__sum  0.686302  0.638249    480.0
# 478                                       Fraud         1  1.000000    481.0
#
#      FDR_rank  Average_rank
# ...

# %%
KSFDR.sort_values(['Average_rank']).tail(81).to_excel('KS_FDR.xlsx')

# %%
df=v.copy()

# %%
df=df[KSFDR.sort_values(['Average_rank']).tail(81)['index']]

# %%
df=df.drop(['Fraud'],axis=1)

# %%
len(df.columns)
# Out:
# 80

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(max_iter = 1000)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
data=scaler.fit_transform(df.to_numpy())
data=pd.DataFrame(data,columns=df.columns)

# %%
for col in list(data.columns):
    a = np.array(data[col].values.tolist())
    data[col] = np.where(a > 9, 10, a).tolist()

# %% [markdown]
# ### 1.1 Wraper - Logistic Regression

# %%
from sklearn.feature_selection import RFECV

# %%
rfecv=RFECV(estimator=model,step=1,cv=3,verbose=1,n_jobs=1,scoring='roc_auc')
rfecv.fit(data,v['Fraud'])
# Out:
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# Fitting estimator with 74 features.
# Fitting estimator with 73 features.
# Fitting estimator with 72 features.
# Fitting estimator with 71 features.
# Fitting estimator with 70 features.
# Fitting estimator with 69 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 61 features.
# Fitting estimator with 60 features.
# Fitting estimator with 59 features.
# Fitting estimator with 58 features.
# Fitting estimator with 57 features.
# Fitting estimator with 56 features.
# Fitting estimator with 55 features.
# ...

# %%
var_selected = pd.DataFrame(sorted(zip(map(lambda x: round(x),rfecv.ranking_),data.columns)),columns = ['ranking', 'variable'])
var_selected.head(25)
# Out:
#     ranking                                     variable
# 0         1                         Merchnum_count0__max
# 1         2           Merch_description_part_count0__max
# 2         3             cardnum-merch_state_count14__max
# 3         4             cardnum-merch_state_count30__max
# 4         5   cardnum-merch_description_part_count3__sum
# 5         6                 cardnum-merchnum_count3__sum
# 6         7                         Merchnum_count3__max
# 7         8                 cardnum-merchnum_count1__max
# 8         9                 cardnum-merchnum_count3__max
# 9        10                         Merchnum_count1__sum
# 10       11                         Merchnum_count1__max
# 11       12  cardnum-merch_description_part_count14__sum
# 12       13  cardnum-merch_description_part_count30__max
# 13       14  cardnum-merch_description_part_count14__max
# 14       15   cardnum-merch_state_merch_zip_count30__max
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,len(rfecv.grid_scores_)+1),rfecv.grid_scores_)
plt.xlabel('Number of features selected')
plt.ylabel('Cross validation score (nb of correct classifications)')
plt.savefig('score1.png')

# %%
var_selected.to_csv('selected_1.csv')

# %% [markdown]
# ### 1.2 Wrapper - second step

# %%
select_column = var_selected[var_selected['ranking'] <= 50].variable.to_list()

# %%
data2 = data[select_column]

# %%
rfecv2=RFECV(estimator=model,step=1,cv=3,verbose=1,n_jobs=1,scoring='roc_auc')
rfecv2.fit(data2,v['Fraud'])
# Out:
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# ...

# %%
var_selected2 = pd.DataFrame(sorted(zip(map(lambda x: round(x),rfecv2.ranking_),data2.columns)),columns = ['ranking', 'variable'])
var_selected2.head(25)
# Out:
#     ranking                                     variable
# 0         1           Merch_description_part_count0__max
# 1         1                         Merchnum_count0__max
# 2         1                         Merchnum_count1__max
# 3         1                         Merchnum_count1__sum
# 4         1                         Merchnum_count3__max
# 5         1  cardnum-merch_description_part_count14__max
# 6         1  cardnum-merch_description_part_count14__sum
# 7         1  cardnum-merch_description_part_count30__max
# 8         1   cardnum-merch_description_part_count3__sum
# 9         1             cardnum-merch_state_count14__max
# 10        1             cardnum-merch_state_count30__max
# 11        1   cardnum-merch_state_merch_zip_count30__max
# 12        1    cardnum-merch_state_merch_zip_count3__sum
# 13        1               cardnum-merch_zip_count14__max
# 14        1                cardnum-merchnum_count14__max
# ...

# %%
var_selected2.to_csv('selected_2.csv')

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,len(rfecv2.grid_scores_)+1),rfecv2.grid_scores_)
plt.xlabel('Number of features selected')
plt.ylabel('Cross validation score (nb of correct classifications)')
plt.savefig('score2.png')

# %%
selected_column = var_selected2[var_selected2['ranking'] == 1].variable.to_list()

# %%
selected_column
# Out:
# ['Merch_description_part_count0__max',
#  'Merchnum_count0__max',
#  'Merchnum_count1__max',
#  'Merchnum_count1__sum',
#  'Merchnum_count3__max',
#  'cardnum-merch_description_part_count14__max',
#  'cardnum-merch_description_part_count14__sum',
#  'cardnum-merch_description_part_count30__max',
#  'cardnum-merch_description_part_count3__sum',
#  'cardnum-merch_state_count14__max',
#  'cardnum-merch_state_count30__max',
#  'cardnum-merch_state_merch_zip_count30__max',
#  'cardnum-merch_state_merch_zip_count3__sum',
#  'cardnum-merch_zip_count14__max',
#  'cardnum-merchnum_count14__max',
#  'cardnum-merchnum_count14__sum',
#  'cardnum-merchnum_count1__max',
#  'cardnum-merchnum_count30__max',
#  'cardnum-merchnum_count3__max',
#  'cardnum-merchnum_count3__sum']

# %%
# from sklearn.ensemble import RandomForestRegressor
# rf = RandomForestRegressor(n_estimators = 50, max_depth = 10, min_samples_leaf = 5)
# rf = RandomForestRegressor()

# %%
selected_column.append('Fraud')

# %%
final = v[selected_column]

# %%
final.to_csv('Selected_variables.csv')
