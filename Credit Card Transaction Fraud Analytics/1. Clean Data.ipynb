# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('cleaning data_3.xlsx', converters={'Merchnum': lambda x: str(x), 'Merch_zip': lambda x : str(x)})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96397 entries, 0 to 96396
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Recnum                  96397 non-null  int64
#  1   Cardnum                 96397 non-null  int64
#  2   Date                    96397 non-null  datetime64[ns]
#  3   Merchnum                93199 non-null  object
#  4   Merch_description       96397 non-null  object
#  5   Merch_state             95464 non-null  object
#  6   Merch_zip               92097 non-null  object
#  7   Amount                  96397 non-null  float64
#  8   Fraud                   96397 non-null  int64
#  9   Merch_description_part  96397 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(5)
# memory usage: 7.4+ MB

# %% [markdown]
# ## 1. Treat Merchnum == 0 as nan

# %%
df['Merchnum'] = df['Merchnum'].replace('0',np.nan)

# %%
df[df['Merchnum'] == '0']
# Out:
# Empty DataFrame
# Columns: [Recnum, Cardnum, Date, Merchnum, Merch_description, Merch_state, Merch_zip, Amount, Fraud, Merch_description_part]
# Index: []

# %% [markdown]
# ## 2. Filling in missing value

# %%
group_merchnum_1 = df.groupby('Merchnum')['Merch_zip'].apply(pd.Series.mode).to_frame().reset_index().groupby('Merchnum').agg({'Merch_zip':'first'})
group_merchnum_2 = df.groupby('Merchnum')['Merch_state'].apply(pd.Series.mode).to_frame().reset_index().groupby('Merchnum').agg({'Merch_state':'first'})

# %%
group_merchnum = df['Merchnum'].unique()
group_merchnum = pd.DataFrame({'Merchnum':group_merchnum})
group_merchnum = group_merchnum.set_index('Merchnum')

# %%
group_merchnum = pd.merge(group_merchnum, group_merchnum_1,left_index = True, right_index = True,how = 'left')
group_merchnum = pd.merge(group_merchnum, group_merchnum_2,left_index = True, right_index = True,how = 'left')

# %%
group_merchnum
# Out:
#               Merch_zip Merch_state
# Merchnum
# 5509006296254     38118          TN
# 61003026333       01803          MA
# 4503082993600     20706          MD
# 6098208200062     45429          OH
# 602608969534      30091          GA
# ...                 ...         ...
# 30165377          60033          IL
# 936337            60123          IL
# 4503092553800     98188          WA
# 3500000004991     23235          VA
# 3500000006160     41042          KY
#
# [13090 rows x 2 columns]

# %%
group_description_1 = df[~df['Merch_description'].str.contains('ADJ')].groupby('Merch_description')['Merch_zip'].apply(pd.Series.mode).to_frame().reset_index().groupby('Merch_description').agg({'Merch_zip':'first'})
group_description_2 = df[~df['Merch_description'].str.contains('ADJ')].groupby('Merch_description')['Merch_state'].apply(pd.Series.mode).to_frame().reset_index().groupby('Merch_description').agg({'Merch_state':'first'})
group_description_3 = df[~df['Merch_description'].str.contains('ADJ')].groupby('Merch_description')['Merchnum'].apply(pd.Series.mode).to_frame().reset_index().groupby('Merch_description').agg({'Merchnum':'first'})

# %%
group_description_4 = df[~df['Merch_description'].str.contains('ADJ')].groupby('Merch_description').agg({'Recnum':'first'})

# %%
group_description = df[~df['Merch_description'].str.contains('ADJ')]
group_description = group_description['Merch_description'].unique()
group_description = pd.DataFrame({'Merch_description':group_description})
group_description = group_description.set_index('Merch_description')

# %%
group_description = pd.merge(group_description,group_description_1,left_index = True, right_index = True, how = 'left')
group_description = pd.merge(group_description,group_description_2,left_index = True, right_index = True, how = 'left')
group_description = pd.merge(group_description,group_description_3,left_index = True, right_index = True, how = 'left')
group_description = pd.merge(group_description,group_description_4,left_index = True, right_index = True, how = 'left')

# %%
group_description['Merch_zip'] = group_description['Merch_zip'].fillna(group_description['Recnum'])
group_description['Merch_state'] = group_description['Merch_state'].fillna(group_description['Recnum'])

# %%
group_description
# Out:
#                         Merch_zip Merch_state       Merchnum  Recnum
# Merch_description
# FEDEX SHP 12/23/09 AB#      38118          TN  5509006296254       1
# SERVICE MERCHANDISE #81     01803          MA    61003026333       2
# OFFICE DEPOT #191           20706          MD  4503082993600       3
# FEDEX SHP 12/28/09 AB#      38118          TN  5509006296254       4
# FEDEX SHP 12/22/09 AB#      38118          TN  5509006296254       6
# ...                           ...         ...            ...     ...
# W G COMPUTER SPLY GRP       60033          IL       30165377   96679
# THE BON MARCHE #8           98188          WA  4503092553800   96714
# TEXACO     22601220094      36043          AL      580000003   96720
# BEST BUY      00004226      23235          VA  3500000004991   96734
# BEST BUY      00001610      41042          KY  3500000006160   96749
#
# [12959 rows x 4 columns]

# %%
group_description.loc['AOAC INTERNATIONAL']
# Out:
# Merch_zip             20877
# Merch_state              MD
# Merchnum       253050503505
# Recnum                10863
# Name: AOAC INTERNATIONAL, dtype: object

# %%
df.head()
# Out:
#    Recnum     Cardnum       Date       Merchnum        Merch_description  \
# 0       1  5142190439 2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
# 1       2  5142183973 2010-01-01    61003026333  SERVICE MERCHANDISE #81
# 2       3  5142131721 2010-01-01  4503082993600        OFFICE DEPOT #191
# 3       4  5142148452 2010-01-01  5509006296254   FEDEX SHP 12/28/09 AB#
# 4       5  5142190439 2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
#
#   Merch_state Merch_zip  Amount  Fraud Merch_description_part
# 0          TN     38118    3.62      0             FEDEXSHPAB
# 1          MA     01803   31.42      0     SERVICEMERCHANDISE
# 2          MD     20706  178.49      0            OFFICEDEPOT
# 3          TN     38118    3.62      0             FEDEXSHPAB
# 4          TN     38118    3.62      0             FEDEXSHPAB

# %% [markdown]
# ### 2.1 Fill state and zip by merchnum group

# %%
df = df.set_index('Merchnum')
df['Merch_state'] = df['Merch_state'].fillna(group_merchnum['Merch_state'])
df['Merch_state'] = df['Merch_state'].replace('nan', np.nan)
df['Merch_state'].count()
# Out:
# 95464

# %%
df['Merch_zip'] = df['Merch_zip'].fillna(group_merchnum['Merch_zip'])
df['Merch_zip'] = df['Merch_zip'].replace('nan', np.nan)
df = df.reset_index()
df['Merch_zip'].count()
# Out:
# 93923

# %% [markdown]
# ### 2.1 Fill state, zip and merchnum by merch_description group

# %%
df = df.set_index('Merch_description')
df['Merch_state'] = df['Merch_state'].fillna(group_description['Merch_state'])
df['Merch_state'] = df['Merch_state'].replace('nan', np.nan)
df['Merch_state'].count()
# Out:
# 95736

# %%
df['Merch_zip'] = df['Merch_zip'].fillna(group_description['Merch_zip'])
df['Merch_zip'] = df['Merch_zip'].replace('nan', np.nan)
df['Merch_zip'].count()
# Out:
# 95701

# %%
df['Merchnum'] = df['Merchnum'].fillna(group_description['Merchnum'])
df['Merchnum'] = df['Merchnum'].replace('nan', np.nan)
df['Merchnum'].count()
# Out:
# 94303

# %%
df = df.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96397 entries, 0 to 96396
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Merch_description       96397 non-null  object
#  1   Merchnum                94303 non-null  object
#  2   Recnum                  96397 non-null  int64
#  3   Cardnum                 96397 non-null  int64
#  4   Date                    96397 non-null  datetime64[ns]
#  5   Merch_state             95736 non-null  object
#  6   Merch_zip               95701 non-null  object
#  7   Amount                  96397 non-null  float64
#  8   Fraud                   96397 non-null  int64
#  9   Merch_description_part  96397 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(5)
# memory usage: 7.4+ MB

# %% [markdown]
# ### 2.3 Filling in missing zip and state using minus recordnum

# %%
df['minus'] = -df['Recnum']

# %%
df['minus'] = df['minus'].astype('str')

# %%
df['Merch_state'] = df['Merch_state'].fillna(df['minus'])
df['Merch_zip'] = df['Merch_zip'].fillna(df['minus'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96397 entries, 0 to 96396
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Merch_description       96397 non-null  object
#  1   Merchnum                94303 non-null  object
#  2   Recnum                  96397 non-null  int64
#  3   Cardnum                 96397 non-null  int64
#  4   Date                    96397 non-null  datetime64[ns]
#  5   Merch_state             96397 non-null  object
#  6   Merch_zip               96397 non-null  object
#  7   Amount                  96397 non-null  float64
#  8   Fraud                   96397 non-null  int64
#  9   Merch_description_part  96397 non-null  object
#  10  minus                   96397 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(6)
# memory usage: 8.1+ MB

# %% [markdown]
# ### 2.4 assign merchnum by grouping by merch_description & state & zip

# %%
df['Merch_state'] = df['Merch_state'].astype('str')
df['Merch_zip'] = df['Merch_zip'].astype('str')

# %%
df['assign'] = df['Merch_description'] + df['Merch_state'] + df['Merch_zip']

# %%
merchnum_missing = df.groupby('assign').agg({'minus':'first'})

# %%
df = df.set_index('assign')
df['Merchnum'] = df['Merchnum'].fillna(merchnum_missing['minus'])
df = df.reset_index()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96397 entries, 0 to 96396
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   assign                  96397 non-null  object
#  1   Merch_description       96397 non-null  object
#  2   Merchnum                96397 non-null  object
#  3   Recnum                  96397 non-null  int64
#  4   Cardnum                 96397 non-null  int64
#  5   Date                    96397 non-null  datetime64[ns]
#  6   Merch_state             96397 non-null  object
#  7   Merch_zip               96397 non-null  object
#  8   Amount                  96397 non-null  float64
#  9   Fraud                   96397 non-null  int64
#  10  Merch_description_part  96397 non-null  object
#  11  minus                   96397 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(7)
# memory usage: 8.8+ MB

# %%
df.head()
# Out:
#                            assign        Merch_description       Merchnum  \
# 0   FEDEX SHP 12/23/09 AB#TN38118   FEDEX SHP 12/23/09 AB#  5509006296254
# 1  SERVICE MERCHANDISE #81MA01803  SERVICE MERCHANDISE #81    61003026333
# 2        OFFICE DEPOT #191MD20706        OFFICE DEPOT #191  4503082993600
# 3   FEDEX SHP 12/28/09 AB#TN38118   FEDEX SHP 12/28/09 AB#  5509006296254
# 4   FEDEX SHP 12/23/09 AB#TN38118   FEDEX SHP 12/23/09 AB#  5509006296254
#
#    Recnum     Cardnum       Date Merch_state Merch_zip  Amount  Fraud  \
# 0       1  5142190439 2010-01-01          TN     38118    3.62      0
# 1       2  5142183973 2010-01-01          MA     01803   31.42      0
# 2       3  5142131721 2010-01-01          MD     20706  178.49      0
# 3       4  5142148452 2010-01-01          TN     38118    3.62      0
# 4       5  5142190439 2010-01-01          TN     38118    3.62      0
#
#   Merch_description_part minus
# 0             FEDEXSHPAB    -1
# 1     SERVICEMERCHANDISE    -2
# 2            OFFICEDEPOT    -3
# 3             FEDEXSHPAB    -4
# 4             FEDEXSHPAB    -5

# %%
df.to_excel('no_missing.xlsx')

# %%
df[df['Merch_description'] == 'AOAC INTERNATIONAL']
# Out:
#                           assign   Merch_description      Merchnum  Recnum  \
# 10850  AOAC INTERNATIONALMD20877  AOAC INTERNATIONAL  253050503505   10863
# 59263  AOAC INTERNATIONALMD20877  AOAC INTERNATIONAL  253050503505   59465
# 59682  AOAC INTERNATIONALMD20877  AOAC INTERNATIONAL  253050503505   59887
# 60907  AOAC INTERNATIONALMD20877  AOAC INTERNATIONAL  253050503505   61120
# 62164  AOAC INTERNATIONALMD20877  AOAC INTERNATIONAL  253050503505   62384
# 63067  AOAC INTERNATIONALMD20877  AOAC INTERNATIONAL  253050503505   63288
# 65286  AOAC INTERNATIONALMD20877  AOAC INTERNATIONAL  253050503505   65511
# 71813  AOAC INTERNATIONALMD20877  AOAC INTERNATIONAL  253050503505   72089
# 85113  AOAC INTERNATIONALMD20877  AOAC INTERNATIONAL  253050503505   85450
# 85561  AOAC INTERNATIONALMD00002  AOAC INTERNATIONAL  253050503505   85903
# 85565  AOAC INTERNATIONALMD20877  AOAC INTERNATIONAL  253050503505   85907
# 85568  AOAC INTERNATIONALMD20877  AOAC INTERNATIONAL  253050503505   85910
# 89551  AOAC INTERNATIONALMD20877  AOAC INTERNATIONAL  253050503505   89897
#
#           Cardnum       Date Merch_state Merch_zip  Amount  Fraud  \
# 10850  5142268678 2010-02-15          MD     20877   929.5      0
# 59263  5142270247 2010-08-03          MD     20877  1225.0      0
# 59682  5142182005 2010-08-04          MD     20877   400.0      0
# 60907  5142270247 2010-08-09          MD     20877   975.0      0
# 62164  5142189945 2010-08-11          MD     20877   750.0      0
# 63067  5142270247 2010-08-14          MD     20877   975.0      0
# 65286  5142270247 2010-08-21          MD     20877    85.0      0
# 71813  5142274543 2010-09-11          MD     20877   475.0      0
# 85113  5142230181 2010-11-05          MD     20877   312.0      0
# 85561  5142189945 2010-11-08          MD     00002   660.0      0
# 85565  5142189945 2010-11-08          MD     20877   660.0      0
# 85568  5142189945 2010-11-08          MD     20877   660.0      0
# 89551  5142158945 2010-11-30          MD     20877   419.0      0
#
#       Merch_description_part   minus
# 10850      AOACINTERNATIONAL  -10863
# 59263      AOACINTERNATIONAL  -59465
# 59682      AOACINTERNATIONAL  -59887
# 60907      AOACINTERNATIONAL  -61120
# 62164      AOACINTERNATIONAL  -62384
# 63067      AOACINTERNATIONAL  -63288
# 65286      AOACINTERNATIONAL  -65511
# 71813      AOACINTERNATIONAL  -72089
# 85113      AOACINTERNATIONAL  -85450
# 85561      AOACINTERNATIONAL  -85903
# 85565      AOACINTERNATIONAL  -85907
# 85568      AOACINTERNATIONAL  -85910
# 89551      AOACINTERNATIONAL  -89897

# %%
df[df['Merch_description'].str.contains('GRAINGER')].tail(20)
# Out:
#                      assign Merch_description       Merchnum  Recnum  \
# 90005  GRAINGER #935OH44056     GRAINGER #935  06-0006692427   90351
# 90034  GRAINGER #937IL60188     GRAINGER #937  06-0004269242   90381
# 90801  GRAINGER #236MI48104     GRAINGER #236  06-3666055741   91150
# 92070  GRAINGER #330NC27834     GRAINGER #330         -22812   92420
# 92266  GRAINGER #637NC27616     GRAINGER #637  06-3666057882   92616
# 92587  GRAINGER #328NC27406     GRAINGER #328          -8165   92937
# 92670  GRAINGER #637NC27616     GRAINGER #637  06-3666057882   93020
# 92763  GRAINGER #933TX76010     GRAINGER #933  06-3666888433   93113
# 93593  GRAINGER #732CA95131     GRAINGER #732          -4837   93943
# 93882  GRAINGER #935OH44056     GRAINGER #935  06-0006692427   94232
# 94261  GRAINGER #236MI48104     GRAINGER #236  06-3666055741   94611
# 94291  GRAINGER #935OH44056     GRAINGER #935  06-0006692427   94641
# 94544  GRAINGER #973IL60089     GRAINGER #973  06-3666654612   94895
# 94666  GRAINGER #973IL60089     GRAINGER #973  06-3666654612   95017
# 94711  GRAINGER #505FL32505     GRAINGER #505  06-3666051134   95062
# 94873  GRAINGER #143IL60101     GRAINGER #143         -95224   95224
# 95056  GRAINGER #632RI02888     GRAINGER #632         -85482   95407
# 95195  GRAINGER #645NC27701     GRAINGER #645  06-3666057873   95546
# 95512  GRAINGER #935OH44056     GRAINGER #935  06-0006692427   95865
# 95605  GRAINGER #935OH44056     GRAINGER #935  06-0006692427   95958
#
#           Cardnum       Date Merch_state Merch_zip  Amount  Fraud  \
# 90005  5142184598 2010-12-01          OH     44056  344.35      0
# 90034  5142188959 2010-12-01          IL     60188   51.03      0
# 90801  5142184598 2010-12-06          MI     48104   10.80      0
# 92070  5142211809 2010-12-10          NC     27834   80.55      0
# 92266  5142211809 2010-12-10          NC     27616  323.46      0
# 92587  5142211809 2010-12-13          NC     27406  256.02      0
# 92670  5142204042 2010-12-13          NC     27616   20.28      0
# 92763  5142250016 2010-12-14          TX     76010  430.52      0
# 93593  5142277104 2010-12-16          CA     95131  876.20      0
# 93882  5142185141 2010-12-17          OH     44056  132.64      0
# 94261  5142185141 2010-12-20          MI     48104    0.72      0
# 94291  5142280637 2010-12-20          OH     44056   21.63      0
# 94544  5142280637 2010-12-20          IL     60089   10.20      0
# 94666  5142184598 2010-12-21          IL     60089  745.75      0
# 94711  5142154945 2010-12-21          FL     32505  225.73      0
# 94873  5142184598 2010-12-22          IL     60101  293.25      0
# 95056  5142280637 2010-12-22          RI     02888   11.49      0
# 95195  5142218143 2010-12-23          NC     27701   41.29      0
# 95512  5142184598 2010-12-27          OH     44056  381.90      0
# 95605  5142280637 2010-12-27          OH     44056   26.82      0
#
#       Merch_description_part   minus
# 90005               GRAINGER  -90351
# 90034               GRAINGER  -90381
# 90801               GRAINGER  -91150
# 92070               GRAINGER  -92420
# 92266               GRAINGER  -92616
# 92587               GRAINGER  -92937
# 92670               GRAINGER  -93020
# 92763               GRAINGER  -93113
# 93593               GRAINGER  -93943
# 93882               GRAINGER  -94232
# 94261               GRAINGER  -94611
# 94291               GRAINGER  -94641
# 94544               GRAINGER  -94895
# 94666               GRAINGER  -95017
# 94711               GRAINGER  -95062
# 94873               GRAINGER  -95224
# 95056               GRAINGER  -95407
# 95195               GRAINGER  -95546
# 95512               GRAINGER  -95865
# 95605               GRAINGER  -95958

# %%
df[df['Merch_description'].str.contains('CELLULAR ONE')].tail(20)
# Out:
#                                 assign         Merch_description  \
# 18204              CELLULAR ONECA94080              CELLULAR ONE
# 22953              CELLULAR ONEMI49686              CELLULAR ONE
# 31708           CELLULAR ONE 10OR97330           CELLULAR ONE 10
# 34457  CELLULAR ONE           8MT59401  CELLULAR ONE           8
# 34713          CELLULAR ONE #21CA94103          CELLULAR ONE #21
# 52209            CELLULAR ONE 9OR97365            CELLULAR ONE 9
# 54313           CELLULAR ONE 10OR97330           CELLULAR ONE 10
# 54360         CELLULAR ONE #290MT59601         CELLULAR ONE #290
# 65758              CELLULAR ONECA94080              CELLULAR ONE
# 67725              CELLULAR ONEFL32504              CELLULAR ONE
# 81115      CELLULAR ONE OF SWFLFL32501      CELLULAR ONE OF SWFL
# 92322  CELLULAR ONE           7MT59601  CELLULAR ONE           7
# 92526    CELLULAR ONE        02OR97321    CELLULAR ONE        02
# 94223           CELLULAR ONE 10OR97330           CELLULAR ONE 10
# 94636           CELLULAR ONE 10OR97330           CELLULAR ONE 10
#
#             Merchnum  Recnum     Cardnum       Date Merch_state Merch_zip  \
# 18204   674678180330   18233  5142261097 2010-03-14          CA     94080
# 22953  9013200038298   23002  5142174719 2010-03-29          MI     49686
# 31708  08-3508354542   31795  5142234238 2010-05-01          OR     97330
# 34457         -34561   34561  5142189667 2010-05-10          MT     59401
# 34713   674088896331   34818  5142113833 2010-05-11          CA     94103
# 52209  08-3508354479   52389  5142235358 2010-07-12          OR     97365
# 54313  08-3508354542   54503  5142234238 2010-07-19          OR     97330
# 54360  08-0080002333   54550  5142189667 2010-07-19          MT     59601
# 65758   674678180330   65984  5142261097 2010-08-22          CA     94080
# 67725   975096999222   67962  5142156165 2010-08-29          FL     32504
# 81115   975096916221   81441  5142155800 2010-10-14          FL     32501
# 92322         -92672   92672  5142189667 2010-12-11          MT     59601
# 92526  08-0904173337   92876  5142234238 2010-12-13          OR     97321
# 94223  08-3508354542   94573  5142160778 2010-12-19          OR     97330
# 94636  08-3508354542   94987  5142160778 2010-12-21          OR     97330
#
#         Amount  Fraud Merch_description_part   minus
# 18204   994.80      0            CELLULARONE  -18233
# 22953   325.12      0            CELLULARONE  -23002
# 31708   359.98      0            CELLULARONE  -31795
# 34457    59.99      0            CELLULARONE  -34561
# 34713    59.97      0            CELLULARONE  -34818
# 52209    29.00      0            CELLULARONE  -52389
# 54313    25.00      0            CELLULARONE  -54503
# 54360   110.00      0            CELLULARONE  -54550
# 65758   345.99      0            CELLULARONE  -65984
# 67725    15.00      0            CELLULARONE  -67962
# 81115   259.78      0      CELLULARONEOFSWFL  -81441
# 92322    29.99      0            CELLULARONE  -92672
# 92526    50.00      0            CELLULARONE  -92876
# 94223    84.44      1            CELLULARONE  -94573
# 94636  1230.82      1            CELLULARONE  -94987
